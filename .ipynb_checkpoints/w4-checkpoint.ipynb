# %%
import pandas as pd
import numpy as np
import torch
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
import time
import gc
import pickle
# %matplotlib inline

# %%
data = pd.read_csv("Workshop_Backtest.csv")

# %%
def sharpe_ratio(actualReturn, signals, return_stat=False, return_accumulate=False):
    if actualReturn.shape != signals.shape:
        raise AssertionError(f"Backtest shape {actualReturn.shape}, got {signals.shape}")
    dailyReturns = (actualReturn * signals)
    if len(dailyReturns.shape) > 1 and dailyReturns.shape[1] > 1:
        dailyReturns = dailyReturns.mean(axis=1)
    returns = [dailyReturns.mean() / dailyReturns.std() * np.sqrt(240)]
    if return_stat:
        returns.append(dailyReturns.mean())
        returns.append(dailyReturns.std())
    if return_accumulate:
        returns.append(dailyReturns.sum())
    return returns if len(returns) > 1 else returns[0]

# %%
actual_returns = data[data['datetime'] >= '2017/1/1'].iloc[:, 1:]

# %%
bt_index = actual_returns.iloc[0].name

# %%
bt_index
# Out:
# 1699

# %%
data
# Out:
#        datetime        CF        SR        TA        al        au         c  \
# 0      2010/1/5  0.011700  0.010348  0.011220  0.048953  0.011921  0.012156
# 1      2010/1/6 -0.024954 -0.035594 -0.031634 -0.043162 -0.016297 -0.009922
# 2      2010/1/7  0.006552 -0.029944  0.007801  0.009022  0.029701  0.015823
# 3      2010/1/8  0.003254 -0.000179 -0.007741  0.013691 -0.005040 -0.006231
# 4     2010/1/11 -0.025361 -0.007719 -0.013896 -0.049063 -0.026535 -0.014107
# ...         ...       ...       ...       ...       ...       ...       ...
# 2785  2021/6/23  0.000945 -0.002906 -0.002797 -0.004259 -0.001391 -0.001161
# 2786  2021/6/24  0.008816  0.008927  0.036859  0.018979 -0.000107  0.002713
# 2787  2021/6/25  0.002809  0.000181  0.002318 -0.011280 -0.003323  0.007731
# 2788  2021/6/28  0.000000  0.007222 -0.016962  0.000796 -0.014412  0.002301
# 2789  2021/6/29 -0.003735  0.005377 -0.001176 -0.000530  0.001964 -0.000383
#
#             cu         l         m         p        rb        ru         v  \
# 0     0.034943  0.005915  0.011528  0.012012  0.010009  0.028698  0.000648
# 1    -0.028508 -0.033712 -0.030935 -0.040734 -0.033175 -0.010413 -0.019430
# 2     0.019672  0.006085  0.005376  0.006187  0.000446  0.018066 -0.004624
# 3    -0.009486 -0.000806 -0.011698 -0.015651  0.001782  0.007605 -0.009954
# 4    -0.037981 -0.050040 -0.029422 -0.037763 -0.020231 -0.027869 -0.022788
# ...        ...       ...       ...       ...       ...       ...       ...
# 2785 -0.003336  0.008197 -0.003260 -0.015468 -0.006221  0.006939 -0.013458
# 2786  0.002329  0.013759  0.010110  0.022112  0.028271  0.007657  0.013642
# 2787 -0.005663  0.016039  0.013247  0.003985  0.006088 -0.003419  0.016969
# 2788 -0.007886 -0.006072  0.007844  0.012759 -0.010346 -0.018300  0.001726
# 2789  0.015602  0.000611  0.003459  0.010918  0.022880 -0.007767 -0.001723
#
#              y        zn
# 0     0.010202  0.041029
# 1    -0.033251 -0.038521
# 2     0.002293  0.002316
# 3    -0.018302 -0.006932
# 4    -0.031072 -0.046999
# ...        ...       ...
# 2785 -0.012977 -0.001369
# 2786  0.019102  0.002742
# 2787 -0.010224 -0.010255
# 2788  0.012051  0.006447
# 2789  0.006075  0.012583
#
# [2790 rows x 16 columns]

# %%
# requirement:
# get multi-dimensional data
# get include other column data
# get test data

# %%
X = data.iloc[:, 1:].values

# %%
class SequenceDataLoader:
    
    def __len__(self):
        for i in self.y.values():
            return i.shape[0] - 1
    
    def get_include_other(self, index, col_name):
        return self.X[index], self.y[col_name][index], self.X[index+1][-1].reshape(1, -1)
    
    def get_single(self, index, col_name):
        return self.X[col_name][index], self.y[col_name][index], self.X[col_name][index+1][-1].reshape(1, -1)
    
    def __init__(self, df, date_from, window_size, include_other):
        bt_index = df[df['datetime'] >= date_from].iloc[0].name - window_size - 1
        columns = len(df.columns) - 1

        if include_other:
            sample_shape = (window_size, columns)
            self.X = np.lib.stride_tricks.sliding_window_view(df.iloc[bt_index:, 1:].values, sample_shape, axis=(0,1)) # (nFeature, sFeature, sCol)
            self.X = self.X.reshape(-1, window_size, columns)
        else:
            self.X = {}
            for col in df.columns:
                self.X[col] = np.lib.stride_tricks.sliding_window_view(df[col].iloc[bt_index:].values, window_size) # (nWindow, sFeature)
                self.X[col] = self.X[col].reshape(-1, window_size, columns)
        self.y = {}
        for col in df.columns:
            self.y[col] = np.lib.stride_tricks.sliding_window_view(df[col].iloc[bt_index+1:].values, window_size)
            
        self.get = self.get_include_other if include_other else self.get_single

# %%
def evaluate_loader(estimator, dataLoader=None,  data=None, date_from = None, window_size = None, include_other=None):
    signal = np.zeros_like(actual_returns)
    if dataloader is None:
        dataLoader = SequenceDataLoader(data, date_from, window_size, include_other)
    for col_idx, col_name in enumerate(actual_returns.columns):
        col_signal = np.zeros((len(signal)))
        for i in range(len(dataLoader)):
            train_X, train_y, test_X = dataLoader.get(i, col_name)
            estimator.fit(train_X, train_y)
            col_signal[i] = estimator.predict(test_X)
        signal[:,col_idx] = col_signal
    signal = np.where(signal > 0, 1, -1)
    return sharpe_ratio(actual_returns, signal)

# %%
evaluate_loader(LinearRegression(n_jobs=-1), data, '2017/1/1', 1500, True)
# Out:
# 1.8155104487733784

# %%
# param:
#   window size
#   feature size
#   include other?
#   L1, L2
perf = {}
date_from = '2017/1/1'
max_window_size = data[data['datetime'] >= date_from].iloc[0].name - 1
for window_size in tqdm(range(1450, 1551, 20), position=0, leave=False): # window_size
    perf[window_size] = {}
    for include_other in tqdm((True, False),position=1, leave=False):
        include_other_name = "T" if include_other else "F"
        perf[window_size][include_other_name] = evaluate_loader(LinearRegression(n_jobs=-1), data, date_from, window_size, 1, include_other)
        print(f"{window_size} {include_other} {perf[window_size][include_other_name]}")
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# 1450 True 1.8431915499439744
# 1450 False 0.23924209221918769
#   0%|          | 0/2 [00:00<?, ?it/s]
# 1470 True 1.9111789959830188
# 1470 False 0.32087885517896614
#   0%|          | 0/2 [00:00<?, ?it/s]
# 1490 True 1.8015983120295591
# 1490 False 0.4728122816139446
#   0%|          | 0/2 [00:00<?, ?it/s]
# 1510 True 1.7609439230831372
# 1510 False 0.5999575958313383
#   0%|          | 0/2 [00:00<?, ?it/s]
# 1530 True 1.8069147859382395
# 1530 False 0.5757277097994494
#   0%|          | 0/2 [00:00<?, ?it/s]
# 1550 True 1.8174215512195817
# 1550 False 0.5006005299622481

# %%
# param:
#   window size
#   feature size
#   include other?
#   L1, L2
#   
date_from = '2017/1/1'
max_window_size = data[data['datetime'] >= date_from].iloc[0].name - 1
for window_size in tqdm(range(1570, 1651, 20), position=0, leave=False): # window_size
    perf[window_size] = {}
    for include_other in tqdm((True, False),position=1, leave=False):
        include_other_name = "T" if include_other else "F"
        perf[window_size][include_other_name] = evaluate_loader(LinearRegression(n_jobs=-1), data, date_from, window_size, 1, include_other)
        print(f"{window_size} {include_other} {perf[window_size][include_other_name]}")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# 1570 True 1.816347927897378
# 1570 False 0.6040802691556377
#   0%|          | 0/2 [00:00<?, ?it/s]
# 1590 True 1.8256459156436848
# 1590 False 0.6740884657346597
#   0%|          | 0/2 [00:00<?, ?it/s]
# 1610 True 1.7958792371448793
# 1610 False 0.7430503950304237
#   0%|          | 0/2 [00:00<?, ?it/s]
# 1630 True 1.8345004077741558
# 1630 False 0.599672957521827
#   0%|          | 0/2 [00:00<?, ?it/s]
# 1650 True 1.7271851699458476
# 1650 False 0.7174013208690313

# %%
print(perf)
# Out:
# {1450: {'T': 1.8431915499439744, 'F': 0.23924209221918769}, 1470: {'T': 1.9111789959830188, 'F': 0.32087885517896614}, 1490: {'T': 1.8015983120295591, 'F': 0.4728122816139446}, 1510: {'T': 1.7609439230831372, 'F': 0.5999575958313383}, 1530: {'T': 1.8069147859382395, 'F': 0.5757277097994494}, 1550: {'T': 1.8174215512195817, 'F': 0.5006005299622481}, 1570: {'T': 1.816347927897378, 'F': 0.6040802691556377}, 1590: {'T': 1.8256459156436848, 'F': 0.6740884657346597}, 1610: {'T': 1.7958792371448793, 'F': 0.7430503950304237}, 1630: {'T': 1.8345004077741558, 'F': 0.599672957521827}, 1650: {'T': 1.7271851699458476, 'F': 0.7174013208690313}}

# %%
best_windowsize = 1470

# %%
regularization = {}

# %%
for i in tqdm(range(0, 6)):
    c = 10 ** -i
    regularization[c] = {}
    regularization[c]["L1"] = evaluate_loader(Lasso(alpha=c),data, date_from, best_windowsize, True)
    regularization[c]["L2"] = evaluate_loader(Ridge(alpha=c),data, date_from, best_windowsize, True)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
for i in tqdm(range(0, 6)):
    c = 1 + 10 ** -i
    regularization[c] = {}
    dataloader = SequenceDataLoader(data, date_from, best_windowsize, True)
    regularization[c]["L1"] = evaluate_loader(Lasso(alpha=c), dataLoader=dataloader)
    regularization[c]["L2"] = evaluate_loader(Ridge(alpha=c), dataLoader=dataloader)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
for i in tqdm(range(10)):
    c = 1 + 0.1 * i
    regularization[c] = {}
    dataloader = SequenceDataLoader(data, date_from, best_windowsize, True)
    regularization[c]["L1"] = evaluate_loader(Lasso(alpha=c), dataLoader=dataloader)
    regularization[c]["L2"] = evaluate_loader(Ridge(alpha=c), dataLoader=dataloader)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
sharpe_ratiolarization
# Out:
# {1: {'L1': 0.7362142379834234, 'L2': 2.013350766078257},
#  0.1: {'L1': 0.7362142379834234, 'L2': 2.011566237894905},
#  0.01: {'L1': 0.7362142379834234, 'L2': 1.8346442621011896},
#  0.001: {'L1': 0.7362142379834234, 'L2': 1.8847141466829553},
#  0.0001: {'L1': 0.7362142379834234, 'L2': 1.9187161020778374},
#  1e-05: {'L1': 1.4095498969576274, 'L2': 1.9111789959830188},
#  2: {'L1': 0.7362142379834234, 'L2': 1.7173484458689823},
#  1.1: {'L1': 0.7362142379834234, 'L2': 2.147635477386883},
#  1.01: {'L1': 0.7362142379834234, 'L2': 2.0628190948402114},
#  1.001: {'L1': 0.7362142379834234, 'L2': 1.9984789148824846},
#  1.0001: {'L1': 0.7362142379834234, 'L2': 2.013350766078257},
#  1.00001: {'L1': 0.7362142379834234, 'L2': 2.013350766078257},
#  1.2: {'L1': 0.7362142379834234, 'L2': 2.2111360832613816},
#  1.3: {'L1': 0.7362142379834234, 'L2': 2.082875365345557},
#  1.4: {'L1': 0.7362142379834234, 'L2': 2.0257495513782646},
#  1.5: {'L1': 0.7362142379834234, 'L2': 1.9664307986816665},
#  1.6: {'L1': 0.7362142379834234, 'L2': 1.9016374596808536},
#  1.7000000000000002: {'L1': 0.7362142379834234, 'L2': 1.877500108430448},
#  1.8: {'L1': 0.7362142379834234, 'L2': 1.854353259424297},
#  1.9: {'L1': 0.7362142379834234, 'L2': 1.7857219195275467}}

# %% [markdown]
# # ARMA

# %%
import statsmodels.api as sm
from itertools import product

# %%
col_eval = {}
for col_name in tqdm(actual_returns.columns):
    col_eval[col_name] = sm.tsa.arma_order_select_ic(data[col_name], ic=['aic','bic'],max_ar=4, max_ma=4)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/visu/anaconda3/envs/torch38/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
for name, res in col_eval.items():
    print(f"{name}: AIC {res.aic_min_order} BIC {res.bic_min_order}")
# Out:
# CF: AIC (3, 2) BIC (0, 0)
# SR: AIC (3, 4) BIC (0, 0)
# TA: AIC (0, 0) BIC (0, 0)
# al: AIC (0, 0) BIC (0, 0)
# au: AIC (4, 0) BIC (0, 0)
# c: AIC (0, 2) BIC (1, 0)
# cu: AIC (0, 0) BIC (0, 0)
# l: AIC (4, 0) BIC (0, 0)
# m: AIC (1, 0) BIC (0, 0)
# p: AIC (0, 2) BIC (0, 0)
# rb: AIC (2, 4) BIC (0, 0)
# ru: AIC (0, 2) BIC (0, 0)
# v: AIC (0, 0) BIC (0, 0)
# y: AIC (2, 3) BIC (0, 0)
# zn: AIC (2, 3) BIC (0, 0)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
arima_perf = []
for col_name in tqdm(actual_returns.columns):
    for ar, ma, trend in product(range(0, 11, 5), range(0, 11, 5), ["t", 'c', 'n', 'ct']):
        model = sm.tsa.ARIMA(data[col_name], order=(ar,0, ma),trend=trend).fit()
        pred = model.predict(start=1699, end=len(data)-1, dynamic=False)
        signal = np.where(pred >= 0, 1, -1)
        arima_perf.append((col_name, ar, ma, trend, sharpe_ratio(actual_returns[col_name], signal), signal))
        print(arima_perf[-1][:-1])
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ('CF', 0, 0, 't', 0.34032906491684783)
# ('CF', 0, 0, 'c', 0.34032906491684783)
# ('CF', 0, 0, 'n', -0.34032906491684783)
# ('CF', 0, 0, 'ct', 0.34032906491684783)
# ('CF', 0, 5, 't', 0.8035599991722615)
# ('CF', 0, 5, 'c', 0.8904160817894793)
# ('CF', 0, 5, 'n', 0.8926122125160857)
# ('CF', 0, 5, 'ct', 1.0200098690672652)
# ('CF', 0, 10, 't', 0.23649688831558627)
# ('CF', 0, 10, 'c', 0.31590403752761953)
# ('CF', 0, 10, 'n', 0.273378901369215)
# ('CF', 0, 10, 'ct', 0.6419064300281431)
# ('CF', 5, 0, 't', 0.8961137949538437)
# ('CF', 5, 0, 'c', 0.9026015853661298)
# ('CF', 5, 0, 'n', 0.9170940982966066)
# ('CF', 5, 0, 'ct', 0.8576186045168341)
# ('CF', 5, 5, 't', 0.34032906491684783)
# ('CF', 5, 5, 'c', 0.9891142060472446)
# ('CF', 5, 5, 'n', 1.0611340101491245)
# ('CF', 5, 5, 'ct', 0.34032906491684783)
# ('CF', 5, 10, 't', 1.0293694016396175)
# ('CF', 5, 10, 'c', 0.7555331004267986)
# ('CF', 5, 10, 'n', 0.721718398621042)
# ('CF', 5, 10, 'ct', 0.8977943070296954)
# ('CF', 10, 0, 't', 0.3850359551606497)
# ('CF', 10, 0, 'c', 0.33124770969783657)
# ('CF', 10, 0, 'n', 0.30832468320801404)
# ('CF', 10, 0, 'ct', 0.33373915099682677)
# ('CF', 10, 5, 't', 0.34032906491684783)
# ('CF', 10, 5, 'c', 0.34836645505323505)
# ('CF', 10, 5, 'n', 0.6155003257284039)
# ('CF', 10, 5, 'ct', 0.34032906491684783)
# ('CF', 10, 10, 't', 0.8702536463671159)
# ('CF', 10, 10, 'c', 1.462949247345531)
# ('CF', 10, 10, 'n', 1.5103244898646566)
# ('CF', 10, 10, 'ct', 0.6944327258440829)
# ('SR', 0, 0, 't', -0.14597180003369264)
# ('SR', 0, 0, 'c', -0.14597180003369264)
# ('SR', 0, 0, 'n', -0.14597180003369264)
# ('SR', 0, 0, 'ct', -0.8515962008059428)
# ('SR', 0, 5, 't', 0.5858089183793943)
# ('SR', 0, 5, 'c', 0.6171667398275801)
# ('SR', 0, 5, 'n', 0.5786635319393635)
# ('SR', 0, 5, 'ct', 0.7723613610922581)
# ('SR', 0, 10, 't', 0.5125682059191056)
# ('SR', 0, 10, 'c', 0.4680761964619672)
# ('SR', 0, 10, 'n', 0.6310684164200406)
# ('SR', 0, 10, 'ct', 0.6661899859085568)
# ('SR', 5, 0, 't', 0.7016355147206531)
# ('SR', 5, 0, 'c', 0.617633471836859)
# ('SR', 5, 0, 'n', 0.7194930994043477)
# ('SR', 5, 0, 'ct', 0.6379135730120045)
# ('SR', 5, 5, 't', 0.4771093462706996)
# ('SR', 5, 5, 'c', 0.3238061143874746)
# ('SR', 5, 5, 'n', 0.576222624604238)
# ('SR', 5, 5, 'ct', 0.557407127466845)
# ('SR', 5, 10, 't', 0.19664701710455254)
# ('SR', 5, 10, 'c', 0.1847535949958355)
# ('SR', 5, 10, 'n', 0.11412895484001703)
# ('SR', 5, 10, 'ct', 0.178702743449215)
# ('SR', 10, 0, 't', 0.013659387130026762)
# ('SR', 10, 0, 'c', -0.002991790374664181)
# ('SR', 10, 0, 'n', 0.08029989788417326)
# ('SR', 10, 0, 'ct', 0.09177417172702171)
# ('SR', 10, 5, 't', -0.14597180003369264)
# ('SR', 10, 5, 'c', 0.056795751092972885)
# ('SR', 10, 5, 'n', 0.16908966803799008)
# ('SR', 10, 5, 'ct', -0.14567987922164452)
# ('SR', 10, 10, 't', 0.36174044277637035)
# ('SR', 10, 10, 'c', 0.46513948216569195)
array([-1, -1, -1, ..., -1, -1, -1])),
#  ('CF', 0, 0, 'n', -0.34032906491684783, array([1, 1, 1, ..., 1, 1, 1])),
#  ('CF', 0, 0, 'ct', 0.34032906491684783, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('CF', 0, 5, 't', 0.8035599991722615, array([-1,  1, -1, ...,  1, -1,  1])),
#  ('CF', 0, 5, 'c', 0.8904160817894793, array([1, 1, 1, ..., 1, 1, 1])),
#  ('CF', 0, 5, 'n', 0.8926122125160857, array([1, 1, 1, ..., 1, 1, 1])),
#  ('CF', 0, 5, 'ct', 1.0200098690672652, array([-1,  1, -1, ...,  1, -1,  1])),
#  ('CF', 0, 10, 't', 0.23649688831558627, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 0, 10, 'c', 0.31590403752761953, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 0, 10, 'n', 0.273378901369215, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 0, 10, 'ct', 0.6419064300281431, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 5, 0, 't', 0.8961137949538437, array([-1,  1, -1, ...,  1, -1,  1])),
#  ('CF', 5, 0, 'c', 0.9026015853661298, array([1, 1, 1, ..., 1, 1, 1])),
#  ('CF', 5, 0, 'n', 0.9170940982966066, array([1, 1, 1, ..., 1, 1, 1])),
#  ('CF', 5, 0, 'ct', 0.8576186045168341, array([ 1,  1, -1, ...,  1, -1,  1])),
#  ('CF', 5, 5, 't', 0.34032906491684783, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('CF', 5, 5, 'c', 0.9891142060472446, array([ 1,  1, -1, ...,  1,  1,  1])),
#  ('CF', 5, 5, 'n', 1.0611340101491245, array([ 1,  1, -1, ...,  1,  1,  1])),
#  ('CF', 5, 5, 'ct', 0.34032906491684783, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('CF', 5, 10, 't', 1.0293694016396175, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 5, 10, 'c', 0.7555331004267986, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 5, 10, 'n', 0.721718398621042, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 5, 10, 'ct', 0.8977943070296954, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 10, 0, 't', 0.3850359551606497, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 10, 0, 'c', 0.33124770969783657, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 10, 0, 'n', 0.30832468320801404, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF',
#   10,
#   0,
#   'ct',
#   0.33373915099682677,
#   array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 10, 5, 't', 0.34032906491684783, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('CF', 10, 5, 'c', 0.34836645505323505, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF', 10, 5, 'n', 0.6155003257284039, array([-1,  1, -1, ..., -1, -1,  1])),
#  ('CF',
#   10,
#   5,
#   'ct',
#   0.34032906491684783,
#   array([-1, -1, -1, ..., -1, -1, -1])),
#  ('CF', 10, 10, 't', 0.8702536463671159, array([-1,  1,  1, ..., -1, -1,  1])),
#  ('CF', 10, 10, 'c', 1.462949247345531, array([-1,  1, -1, ...,  1, -1,  1])),
#  ('CF', 10, 10, 'n', 1.5103244898646566, array([-1,  1, -1, ...,  1, -1, -1])),
#  ('CF',
#   10,
#   10,
#   'ct',
#   0.6944327258440829,
#   array([-1,  1,  1, ..., -1, -1,  1])),
#  ('SR', 0, 0, 't', -0.14597180003369264, array([1, 1, 1, ..., 1, 1, 1])),
#  ('SR', 0, 0, 'c', -0.14597180003369264, array([1, 1, 1, ..., 1, 1, 1])),
#  ('SR', 0, 0, 'n', -0.14597180003369264, array([1, 1, 1, ..., 1, 1, 1])),
#  ('SR', 0, 0, 'ct', -0.8515962008059428, array([ 1,  1,  1, ..., -1, -1, -1])),
#  ('SR', 0, 5, 't', 0.5858089183793943, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 0, 5, 'c', 0.6171667398275801, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 0, 5, 'n', 0.5786635319393635, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 0, 5, 'ct', 0.7723613610922581, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 0, 10, 't', 0.5125682059191056, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 0, 10, 'c', 0.4680761964619672, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 0, 10, 'n', 0.6310684164200406, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 0, 10, 'ct', 0.6661899859085568, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 0, 't', 0.7016355147206531, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 0, 'c', 0.617633471836859, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 0, 'n', 0.7194930994043477, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 0, 'ct', 0.6379135730120045, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 5, 't', 0.4771093462706996, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 5, 'c', 0.3238061143874746, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 5, 'n', 0.576222624604238, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 5, 'ct', 0.557407127466845, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 10, 't', 0.19664701710455254, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 10, 'c', 0.1847535949958355, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 10, 'n', 0.11412895484001703, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 5, 10, 'ct', 0.178702743449215, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR',
#   10,
#   0,
#   't',
#   0.013659387130026762,
#   array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR',
#   10,
#   0,
#   'c',
#   -0.002991790374664181,
#   array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 10, 0, 'n', 0.08029989788417326, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR',
#   10,
#   0,
#   'ct',
#   0.09177417172702171,
#   array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 10, 5, 't', -0.14597180003369264, array([1, 1, 1, ..., 1, 1, 1])),
#  ('SR',
#   10,
#   5,
#   'c',
#   0.056795751092972885,
#   array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR', 10, 5, 'n', 0.16908966803799008, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR',
#   10,
#   5,
#   'ct',
#   -0.14567987922164452,
#   array([ 1,  1,  1, ..., -1, -1, -1])),
#  ('SR',
#   10,
#   10,
#   't',
#   0.36174044277637035,
#   array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('SR',
#   10,
#   10,
#   'c',
#   0.46513948216569195,
#   array([-1, -1, -1, ..., -1, -1, -1])),
#  ('SR',
#   10,
#   10,
#   'n',
#   0.29107164481395215,
#   array([-1, -1, -1, ..., -1, -1, -1])),
#  ('SR',
#   10,
#   10,
#   'ct',
#   0.38803988566843234,
#   array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('TA', 0, 0, 't', 0.014267771770397071, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('TA', 0, 0, 'c', 0.014267771770397071, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('TA', 0, 0, 'n', -0.014267771770397071, array([1, 1, 1, ..., 1, 1, 1])),
#  ('TA',
#   0,
#   0,
#   'ct',
#   0.014267771770397071,
#   array([-1, -1, -1, ..., -1, -1, -1])),
#  ('TA', 0, 5, 't', 0.641931807641718, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 0, 5, 'c', 0.7348272363762325, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 0, 5, 'n', 0.5518362671416845, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 0, 5, 'ct', 0.5104246136860368, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 0, 10, 't', 1.673601151285278, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 0, 10, 'c', 1.6178615037516684, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 0, 10, 'n', 1.5072163788536965, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 0, 10, 'ct', 1.4431732986469898, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 5, 0, 't', 0.40715125933661245, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 5, 0, 'c', 0.5323119282087595, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 5, 0, 'n', 0.44415666081281807, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 5, 0, 'ct', 0.5721381859517675, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 5, 5, 't', 0.781189863854094, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 5, 5, 'c', 0.8571079209714351, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('TA', 5, 5, 'n', 1.0483878740837176, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('TA', 5, 5, 'ct', 0.7571365644559072, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('TA', 5, 10, 't', 1.4618153233680786, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 5, 10, 'c', 1.3130385473615194, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 5, 10, 'n', 1.5022133974940997, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('TA', 5, 10, 'ct', 1.4588388324104962, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('TA', 10, 0, 't', 1.756231172272395, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 10, 0, 'c', 1.7828327176809273, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 10, 0, 'n', 1.7745884153196623, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 10, 0, 'ct', 1.6773368366118004, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA',
#   10,
#   5,
#   't',
#   0.014267771770397071,
#   array([-1, -1, -1, ..., -1, -1, -1])),
#  ('TA', 10, 5, 'c', 1.6371349279096088, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 10, 5, 'n', 1.5049334850244787, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 10, 5, 'ct', 0.6209670115998187, array([-1, -1, -1, ...,  1,  1,  1])),
#  ('TA', 10, 10, 't', 1.7411846167340537, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 10, 10, 'c', 1.6507686021244816, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA', 10, 10, 'n', 1.5392654700935162, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('TA',
#   10,
#   10,
#   'ct',
#   1.6060095839684434,
#   array([-1, -1, -1, ...,  1, -1, -1])),
#  ('al', 0, 0, 't', 0.6461745685382395, array([1, 1, 1, ..., 1, 1, 1])),
#  ('al', 0, 0, 'c', 0.6461745685382395, array([1, 1, 1, ..., 1, 1, 1])),
#  ('al', 0, 0, 'n', 0.6461745685382395, array([1, 1, 1, ..., 1, 1, 1])),
#  ('al', 0, 0, 'ct', 0.6461745685382395, array([1, 1, 1, ..., 1, 1, 1])),
#  ('al', 0, 5, 't', 1.0052305525884606, array([ 1,  1,  1, ..., -1,  1, -1])),
#  ('al', 0, 5, 'c', 0.6251183160950469, array([ 1, -1,  1, ..., -1,  1, -1])),
#  ('al', 0, 5, 'n', 0.43267167302953047, array([-1, -1,  1, ..., -1,  1, -1])),
#  ('al', 0, 5, 'ct', 1.2956133474985623, array([ 1,  1,  1, ...,  1,  1, -1])),
#  ('al', 0, 10, 't', 1.9764951658869807, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('al', 0, 10, 'c', 1.711306471653945, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('al', 0, 10, 'n', 1.729907299038629, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('al', 0, 10, 'ct', 2.159688367983888, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('al', 5, 0, 't', 0.8457739736351124, array([ 1,  1,  1, ..., -1,  1, -1])),
#  ('al', 5, 0, 'c', 0.519613174858353, array([ 1, -1,  1, ..., -1,  1, -1])),
#  ('al', 5, 0, 'n', 0.7914680086739933, array([ 1, -1,  1, ..., -1,  1, -1])),
#  ('al', 5, 0, 'ct', 1.2075967656946536, array([ 1,  1,  1, ..., -1,  1,  1])),
#  ('al', 5, 5, 't', 0.7170654945784265, array([ 1,  1,  1, ..., -1,  1, -1])),
#  ('al', 5, 5, 'c', 0.6205855062018497, array([ 1, -1,  1, ..., -1,  1, -1])),
#  ('al', 5, 5, 'n', 0.34112961681077403, array([ 1, -1,  1, ..., -1,  1, -1])),
#  ('al', 5, 5, 'ct', 0.8517340024582684, array([ 1,  1,  1, ..., -1,  1,  1])),
#  ('al', 5, 10, 't', 1.7056105482485833, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('al', 5, 10, 'c', 1.7034281795378123, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('al', 5, 10, 'n', 1.7008289850503346, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('al', 5, 10, 'ct', 2.0278898895108695, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('al', 10, 0, 't', 1.6955659771064686, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('al', 10, 0, 'c', 2.038005642524934, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('al', 10, 0, 'n', 1.9134692908715654, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('al', 10, 0, 'ct', 1.8114006995812173, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('al', 10, 5, 't', 0.6461745685382395, array([1, 1, 1, ..., 1, 1, 1])),
#  ('al', 10, 5, 'c', 1.039367734451448, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('al', 10, 5, 'n', 1.1150923436380848, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('al', 10, 5, 'ct', 0.6461745685382395, array([1, 1, 1, ..., 1, 1, 1])),
#  ('al', 10, 10, 't', 0.6461745685382395, array([1, 1, 1, ..., 1, 1, 1])),
#  ('al', 10, 10, 'c', 1.0162289537116556, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('al', 10, 10, 'n', 1.4481473652202308, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('al', 10, 10, 'ct', 0.6461745685382395, array([1, 1, 1, ..., 1, 1, 1])),
#  ('au', 0, 0, 't', 0.4246743047260884, array([1, 1, 1, ..., 1, 1, 1])),
#  ('au', 0, 0, 'c', 0.4246743047260884, array([1, 1, 1, ..., 1, 1, 1])),
#  ('au', 0, 0, 'n', 0.4246743047260884, array([1, 1, 1, ..., 1, 1, 1])),
#  ('au', 0, 0, 'ct', 0.4246743047260884, array([1, 1, 1, ..., 1, 1, 1])),
#  ('au', 0, 5, 't', 1.5295251687246463, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('au', 0, 5, 'c', 1.6364530034268896, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('au', 0, 5, 'n', 1.2054772532485518, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('au', 0, 5, 'ct', 1.6630100222592945, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('au', 0, 10, 't', 1.5286886645083801, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 0, 10, 'c', 1.48575626355849, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 0, 10, 'n', 1.3691329204756986, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 0, 10, 'ct', 1.5262077065218786, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 5, 0, 't', 1.6457140358551137, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('au', 5, 0, 'c', 1.3673298667766083, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('au', 5, 0, 'n', 1.0590575859138605, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('au', 5, 0, 'ct', 1.4659063185063077, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('au', 5, 5, 't', 1.2041461913032296, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('au', 5, 5, 'c', 1.2753854006378509, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('au', 5, 5, 'n', 1.4175984964226351, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('au', 5, 5, 'ct', 1.2223833526436938, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('au', 5, 10, 't', 1.3981136356838881, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 5, 10, 'c', 1.5102355367187448, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 5, 10, 'n', 1.2095520256590055, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 5, 10, 'ct', 1.4112117316785693, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 10, 0, 't', 1.3900531112200072, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 10, 0, 'c', 1.4168880311214584, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 10, 0, 'n', 1.2675219488673402, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 10, 0, 'ct', 1.4326731172136078, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 10, 5, 't', 0.4246743047260884, array([1, 1, 1, ..., 1, 1, 1])),
#  ('au', 10, 5, 'c', 1.5084564025261942, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 10, 5, 'n', 1.409748346796113, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('au', 10, 5, 'ct', 0.4246743047260884, array([1, 1, 1, ..., 1, 1, 1])),
#  ('au', 10, 10, 't', 1.4064203511721203, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('au', 10, 10, 'c', 1.4364575044387244, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('au', 10, 10, 'n', 1.4154173961384435, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('au',
#   10,
#   10,
#   'ct',
#   1.4489424652965288,
#   array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('c', 0, 0, 't', 0.6862951268015083, array([1, 1, 1, ..., 1, 1, 1])),
#  ('c', 0, 0, 'c', 0.6862951268015083, array([1, 1, 1, ..., 1, 1, 1])),
#  ('c', 0, 0, 'n', 0.6862951268015083, array([1, 1, 1, ..., 1, 1, 1])),
#  ('c', 0, 0, 'ct', 0.6862951268015083, array([1, 1, 1, ..., 1, 1, 1])),
#  ('c', 0, 5, 't', 0.8085608846887206, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('c', 0, 5, 'c', 0.7812791054770724, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('c', 0, 5, 'n', -0.04666423939866109, array([-1, -1,  1, ...,  1, -1,  1])),
#  ('c', 0, 5, 'ct', 0.6741885312987294, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('c', 0, 10, 't', 0.7082032132237924, array([-1,  1,  1, ...,  1, -1, -1])),
#  ('c', 0, 10, 'c', 0.5817943346112299, array([-1,  1,  1, ...,  1, -1, -1])),
#  ('c', 0, 10, 'n', 0.4890903592455454, array([-1,  1,  1, ..., -1, -1, -1])),
#  ('c', 0, 10, 'ct', 0.692664294534236, array([-1,  1,  1, ...,  1, -1, -1])),
#  ('c', 5, 0, 't', 0.8413422966671089, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('c', 5, 0, 'c', 0.7386126175505169, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('c', 5, 0, 'n', -0.03364036876666812, array([-1, -1,  1, ...,  1, -1,  1])),
#  ('c', 5, 0, 'ct', 0.7557840913525642, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('c', 5, 5, 't', 0.5090807222398355, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('c', 5, 5, 'c', 0.1930191933717357, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('c', 5, 5, 'n', -0.6335282116123195, array([-1,  1,  1, ...,  1, -1,  1])),
#  ('c', 5, 5, 'ct', 0.5115392292784386, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('c', 5, 10, 't', 0.5931567251391987, array([-1,  1,  1, ...,  1, -1,  1])),
#  ('c', 5, 10, 'c', 0.4806356577509414, array([-1,  1,  1, ..., -1, -1,  1])),
#  ('c', 5, 10, 'n', 0.5844860326866308, array([-1,  1,  1, ..., -1, -1,  1])),
#  ('c', 5, 10, 'ct', 0.5573700989523581, array([-1,  1,  1, ..., -1, -1,  1])),
#  ('c', 10, 0, 't', 0.7792273492171645, array([-1,  1,  1, ...,  1, -1, -1])),
#  ('c', 10, 0, 'c', 0.6333793453832253, array([-1,  1,  1, ...,  1, -1, -1])),
#  ('c', 10, 0, 'n', 0.5291436297239406, array([-1,  1,  1, ..., -1, -1, -1])),
#  ('c', 10, 0, 'ct', 0.7506691759854567, array([-1,  1,  1, ...,  1, -1, -1])),
#  ('c', 10, 5, 't', 0.6862951268015083, array([1, 1, 1, ..., 1, 1, 1])),
#  ('c', 10, 5, 'c', 0.6862951268015083, array([1, 1, 1, ..., 1, 1, 1])),
#  ('c', 10, 5, 'n', 0.10605074236345319, array([-1, -1,  1, ...,  1, -1, -1])),
#  ('c', 10, 5, 'ct', 0.6862951268015083, array([1, 1, 1, ..., 1, 1, 1])),
#  ('c', 10, 10, 't', 0.6862951268015083, array([1, 1, 1, ..., 1, 1, 1])),
#  ('c', 10, 10, 'c', 0.6862951268015083, array([1, 1, 1, ..., 1, 1, 1])),
#  ('c', 10, 10, 'n', 0.6262514844823758, array([-1,  1,  1, ..., -1, -1, -1])),
#  ('c', 10, 10, 'ct', 0.6862951268015083, array([1, 1, 1, ..., 1, 1, 1])),
#  ('cu', 0, 0, 't', 0.5392307397144314, array([1, 1, 1, ..., 1, 1, 1])),
#  ('cu', 0, 0, 'c', 0.5392307397144314, array([1, 1, 1, ..., 1, 1, 1])),
#  ('cu', 0, 0, 'n', 0.5392307397144314, array([1, 1, 1, ..., 1, 1, 1])),
#  ('cu', 0, 0, 'ct', 0.5392307397144314, array([1, 1, 1, ..., 1, 1, 1])),
#  ('cu', 0, 5, 't', 0.6857114536029136, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('cu', 0, 5, 'c', 0.718045329681047, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('cu', 0, 5, 'n', 0.9302024787318378, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('cu', 0, 5, 'ct', 0.6991814447643897, array([ 1, -1, -1, ...,  1,  1, -1])),
#  ('cu', 0, 10, 't', 0.27037032074368605, array([ 1, -1, -1, ...,  1, -1, -1])),
#  ('cu', 0, 10, 'c', 0.14321588964105864, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('cu', 0, 10, 'n', 0.10669438395956495, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('cu',
#   0,
#   10,
#   'ct',
#   0.44653825186046653,
#   array([ 1, -1, -1, ...,  1, -1, -1])),
#  ('cu', 5, 0, 't', 0.5673508740674217, array([ 1, -1, -1, ..., -1,  1, -1])),
#  ('cu', 5, 0, 'c', 0.5257207982591374, array([-1, -1, -1, ..., -1,  1, -1])),
#  ('cu', 5, 0, 'n', 0.7364925632608555, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('cu', 5, 0, 'ct', 0.43563533416139283, array([ 1, -1, -1, ...,  1,  1,  1])),
#  ('cu', 5, 5, 't', 0.5392307397144314, array([1, 1, 1, ..., 1, 1, 1])),
#  ('cu', 5, 5, 'c', 0.5775479428975369, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('cu', 5, 5, 'n', 0.6397926176553774, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('cu', 5, 5, 'ct', 0.5392307397144314, array([1, 1, 1, ..., 1, 1, 1])),
#  ('cu',
#   5,
#   10,
#   't',
#   -0.007257986361773548,
#   array([-1, -1, -1, ..., -1, -1, -1])),
#  ('cu', 5, 10, 'c', 0.13751018443640917, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('cu', 5, 10, 'n', 0.24106084392502802, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('cu',
#   5,
#   10,
#   'ct',
#   0.09557066116102807,
#   array([-1, -1, -1, ..., -1, -1, -1])),
#  ('cu', 10, 0, 't', 0.07984158468615937, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('cu', 10, 0, 'c', 0.09133258140831584, array([ 1, -1, -1, ...,  1, -1, -1])),
#  ('cu', 10, 0, 'n', 0.14824296730860148, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('cu', 10, 0, 'ct', 0.3320876080503095, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('cu', 10, 5, 't', 0.5392307397144314, array([1, 1, 1, ..., 1, 1, 1])),
#  ('cu', 10, 5, 'c', 0.24404989489421092, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('cu', 10, 5, 'n', 0.35200397326981014, array([ 1, -1, -1, ..., -1, -1, -1])),
#  ('cu', 10, 5, 'ct', 0.5392307397144314, array([1, 1, 1, ..., 1, 1, 1])),
#  ('cu', 10, 10, 't', 0.7097713081347796, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('cu',
#   10,
#   10,
#   'c',
#   0.47895290185104855,
#   array([-1,  1,  1, ..., -1, -1, -1])),
#  ('cu', 10, 10, 'n', 0.6583995758650935, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('cu',
#   10,
#   10,
#   'ct',
#   0.7130108848929186,
#   array([-1,  1, -1, ..., -1, -1, -1])),
#  ('l', 0, 0, 't', 0.003202688586602281, array([1, 1, 1, ..., 1, 1, 1])),
#  ('l', 0, 0, 'c', 0.003202688586602281, array([1, 1, 1, ..., 1, 1, 1])),
#  ('l', 0, 0, 'n', 0.003202688586602281, array([1, 1, 1, ..., 1, 1, 1])),
#  ('l', 0, 0, 'ct', 0.003202688586602281, array([1, 1, 1, ..., 1, 1, 1])),
#  ('l', 0, 5, 't', 0.25539511378944363, array([ 1, -1,  1, ..., -1,  1,  1])),
#  ('l', 0, 5, 'c', -0.04774432423872009, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('l', 0, 5, 'n', -0.11075175303875108, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('l', 0, 5, 'ct', 0.4316297040214349, array([ 1, -1,  1, ..., -1,  1,  1])),
#  ('l', 0, 10, 't', 0.8922181371770317, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('l', 0, 10, 'c', 0.9607541148539618, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('l', 0, 10, 'n', 0.8376856601799975, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('l', 0, 10, 'ct', 0.650013555147558, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('l', 5, 0, 't', 0.343349937521179, array([ 1, -1,  1, ..., -1, -1,  1])),
#  ('l', 5, 0, 'c', 0.201883656956578, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('l', 5, 0, 'n', 0.19750223807389503, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('l', 5, 0, 'ct', 0.4133595784425196, array([ 1, -1,  1, ..., -1,  1,  1])),
#  ('l', 5, 5, 't', -0.014675555797355182, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('l', 5, 5, 'c', -0.22787204055212934, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('l', 5, 5, 'n', 0.22480920157975004, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('l', 5, 5, 'ct', 0.17890358166014714, array([ 1, -1,  1, ..., -1,  1,  1])),
#  ('l', 5, 10, 't', 0.4304069406482532, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('l', 5, 10, 'c', 0.7679123652471729, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('l', 5, 10, 'n', 0.7213231262696697, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('l', 5, 10, 'ct', 0.13204832208187275, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('l', 10, 0, 't', 0.570567470486147, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('l', 10, 0, 'c', 0.906035733024269, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('l', 10, 0, 'n', 0.9030582528317632, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('l', 10, 0, 'ct', 0.7864114656481108, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('l', 10, 5, 't', 0.003202688586602281, array([1, 1, 1, ..., 1, 1, 1])),
#  ('l', 10, 5, 'c', 0.852075581553273, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('l', 10, 5, 'n', 0.873088830011261, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('l', 10, 5, 'ct', 0.003202688586602281, array([1, 1, 1, ..., 1, 1, 1])),
#  ('l', 10, 10, 't', 0.37590335305514405, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('l', 10, 10, 'c', 0.744077966977669, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('l', 10, 10, 'n', 0.9396516761129833, array([ 1, -1,  1, ..., -1, -1, -1])),
#  ('l',
#   10,
#   10,
#   'ct',
#   0.44439019954960696,
#   array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('m', 0, 0, 't', 0.5506794889291825, array([1, 1, 1, ..., 1, 1, 1])),
#  ('m', 0, 0, 'c', 0.5506794889291825, array([1, 1, 1, ..., 1, 1, 1])),
#  ('m', 0, 0, 'n', 0.5506794889291825, array([1, 1, 1, ..., 1, 1, 1])),
#  ('m', 0, 0, 'ct', 0.5506794889291825, array([1, 1, 1, ..., 1, 1, 1])),
#  ('m', 0, 5, 't', 0.413376218787527, array([-1,  1,  1, ...,  1,  1,  1])),
#  ('m', 0, 5, 'c', 0.1398936694750431, array([-1,  1,  1, ...,  1, -1,  1])),
#  ('m', 0, 5, 'n', 0.07864443081891413, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 0, 5, 'ct', 0.09388105006574625, array([-1,  1,  1, ...,  1, -1,  1])),
#  ('m', 0, 10, 't', 0.20431371913570023, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 0, 10, 'c', 0.6484772071677253, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 0, 10, 'n', 0.5292319686113192, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 0, 10, 'ct', 0.4831443634054841, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 5, 0, 't', 0.33495454439483485, array([-1,  1,  1, ...,  1,  1,  1])),
#  ('m', 5, 0, 'c', 0.06804014877080627, array([-1,  1,  1, ...,  1, -1,  1])),
#  ('m', 5, 0, 'n', -0.08761044601679335, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 5, 0, 'ct', 0.02062661914794117, array([-1,  1,  1, ...,  1, -1,  1])),
#  ('m', 5, 5, 't', 0.593318661724473, array([-1, -1,  1, ..., -1,  1,  1])),
#  ('m', 5, 5, 'c', 0.9687454222503052, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 5, 5, 'n', 0.6275324757031974, array([-1,  1,  1, ..., -1, -1, -1])),
#  ('m', 5, 5, 'ct', 0.29193370071503044, array([-1, -1,  1, ..., -1, -1,  1])),
#  ('m', 5, 10, 't', 0.7340940490471084, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 5, 10, 'c', 0.9668776226354732, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 5, 10, 'n', 0.45849975291671596, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 5, 10, 'ct', 0.5909808339079018, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 10, 0, 't', 0.2356154580607688, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 10, 0, 'c', 0.6458057399575579, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 10, 0, 'n', 0.5423541632910246, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 10, 0, 'ct', 0.5674810488114888, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 10, 5, 't', 0.5506794889291825, array([1, 1, 1, ..., 1, 1, 1])),
#  ('m', 10, 5, 'c', 0.4634881387277872, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 10, 5, 'n', 0.36413699808610345, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 10, 5, 'ct', 0.5506794889291825, array([1, 1, 1, ..., 1, 1, 1])),
#  ('m', 10, 10, 't', 0.5506794889291825, array([1, 1, 1, ..., 1, 1, 1])),
#  ('m', 10, 10, 'c', 0.42281252514440276, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 10, 10, 'n', 0.42653825725222566, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('m', 10, 10, 'ct', 0.5506794889291825, array([1, 1, 1, ..., 1, 1, 1])),
#  ('p', 0, 0, 't', 0.3046358151438901, array([1, 1, 1, ..., 1, 1, 1])),
#  ('p', 0, 0, 'c', -0.3046358151438901, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('p', 0, 0, 'n', 0.3046358151438901, array([1, 1, 1, ..., 1, 1, 1])),
#  ('p', 0, 0, 'ct', 0.3046358151438901, array([1, 1, 1, ..., 1, 1, 1])),
#  ('p', 0, 5, 't', 1.161154208470778, array([ 1,  1, -1, ..., -1,  1,  1])),
#  ('p', 0, 5, 'c', 0.909945868433768, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('p', 0, 5, 'n', 1.0416837625042557, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('p', 0, 5, 'ct', 1.408417633150289, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('p', 0, 10, 't', 1.8333948340792199, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('p', 0, 10, 'c', 1.9999891635674971, array([-1, -1, -1, ..., -1,  1, -1])),
#  ('p', 0, 10, 'n', 2.009769079868303, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('p', 0, 10, 'ct', 1.420876369496944, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('p', 5, 0, 't', 1.0815478776420904, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('p', 5, 0, 'c', 1.0885868597251602, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('p', 5, 0, 'n', 1.100684759006566, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('p', 5, 0, 'ct', 1.4239329530296245, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('p', 5, 5, 't', 1.357173418618832, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('p', 5, 5, 'c', 1.0560250492062082, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('p', 5, 5, 'n', 1.0215476548627072, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('p', 5, 5, 'ct', 1.4324476462619078, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('p', 5, 10, 't', 1.9181919854823137, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('p', 5, 10, 'c', 1.7472352799025224, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('p', 5, 10, 'n', 1.8696655050195539, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('p', 5, 10, 'ct', 1.8294489932316094, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('p', 10, 0, 't', 2.0324638586859685, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('p', 10, 0, 'c', 1.9044430599338444, array([-1, -1, -1, ..., -1,  1, -1])),
#  ('p', 10, 0, 'n', 1.8937914199930885, array([-1, -1, -1, ..., -1,  1, -1])),
#  ('p', 10, 0, 'ct', 1.2629321567820195, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('p', 10, 5, 't', 0.3046358151438901, array([1, 1, 1, ..., 1, 1, 1])),
#  ('p', 10, 5, 'c', 2.04848052150455, array([-1, -1, -1, ..., -1,  1, -1])),
#  ('p', 10, 5, 'n', 1.8919093707819048, array([-1, -1, -1, ..., -1,  1, -1])),
#  ('p', 10, 5, 'ct', 0.3046358151438901, array([1, 1, 1, ..., 1, 1, 1])),
#  ('p', 10, 10, 't', 2.2676668187286926, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('p', 10, 10, 'c', 1.7689577576352278, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('p', 10, 10, 'n', 2.0983131242013426, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('p', 10, 10, 'ct', 1.96701991312512, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('rb', 0, 0, 't', 1.2170057486592645, array([1, 1, 1, ..., 1, 1, 1])),
#  ('rb', 0, 0, 'c', 1.2170057486592645, array([1, 1, 1, ..., 1, 1, 1])),
#  ('rb', 0, 0, 'n', 1.2170057486592645, array([1, 1, 1, ..., 1, 1, 1])),
#  ('rb', 0, 0, 'ct', 1.2170057486592645, array([1, 1, 1, ..., 1, 1, 1])),
#  ('rb', 0, 5, 't', 1.1101203518943654, array([-1, -1,  1, ...,  1,  1,  1])),
#  ('rb', 0, 5, 'c', 0.4893568941088993, array([-1, -1, -1, ...,  1,  1,  1])),
#  ('rb', 0, 5, 'n', 0.5689352422763274, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('rb', 0, 5, 'ct', 0.7173971464618989, array([-1, -1,  1, ...,  1,  1,  1])),
#  ('rb', 0, 10, 't', 1.0125565951625586, array([-1,  1,  1, ...,  1,  1, -1])),
#  ('rb', 0, 10, 'c', 0.7360895416302626, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('rb', 0, 10, 'n', 0.5047888649140638, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('rb', 0, 10, 'ct', 0.8086131109910302, array([-1,  1,  1, ...,  1,  1, -1])),
#  ('rb', 5, 0, 't', 0.8313127488563862, array([-1, -1,  1, ...,  1,  1,  1])),
#  ('rb', 5, 0, 'c', 0.5772908868656884, array([-1, -1, -1, ...,  1,  1,  1])),
#  ('rb', 5, 0, 'n', 0.6009529422578507, array([-1, -1, -1, ...,  1,  1,  1])),
#  ('rb', 5, 0, 'ct', 0.7254883207107425, array([-1, -1, -1, ...,  1,  1,  1])),
#  ('rb', 5, 5, 't', 0.5489212366484133, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('rb', 5, 5, 'c', 0.4053762197410806, array([-1,  1, -1, ..., -1,  1,  1])),
#  ('rb', 5, 5, 'n', 0.33063159832612343, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('rb', 5, 5, 'ct', 0.7444621768654378, array([ 1,  1, -1, ..., -1,  1,  1])),
#  ('rb', 5, 10, 't', 0.9852413782345053, array([-1,  1,  1, ...,  1,  1, -1])),
#  ('rb', 5, 10, 'c', 0.7281634018586037, array([-1,  1,  1, ...,  1,  1, -1])),
#  ('rb', 5, 10, 'n', 0.7210871056737179, array([-1, -1,  1, ...,  1,  1, -1])),
#  ('rb', 5, 10, 'ct', 1.1764416820043104, array([-1,  1,  1, ...,  1,  1, -1])),
#  ('rb', 10, 0, 't', 0.9852376833694924, array([-1,  1,  1, ...,  1,  1, -1])),
#  ('rb', 10, 0, 'c', 0.792147610358137, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('rb', 10, 0, 'n', 0.7587306964372155, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('rb', 10, 0, 'ct', 1.0833363733686243, array([-1,  1,  1, ...,  1,  1, -1])),
#  ('rb', 10, 5, 't', 1.2170057486592645, array([1, 1, 1, ..., 1, 1, 1])),
#  ('rb', 10, 5, 'c', 0.7896663119133422, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('rb', 10, 5, 'n', 1.028590151671234, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('rb', 10, 5, 'ct', 1.2170057486592645, array([1, 1, 1, ..., 1, 1, 1])),
#  ('rb', 10, 10, 't', 1.2170057486592645, array([1, 1, 1, ..., 1, 1, 1])),
#  ('rb', 10, 10, 'c', 0.8150038823195694, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('rb', 10, 10, 'n', 0.2607102481701457, array([-1,  1,  1, ...,  1,  1, -1])),
#  ('rb', 10, 10, 'ct', 1.2170057486592645, array([1, 1, 1, ..., 1, 1, 1])),
#  ('ru', 0, 0, 't', 0.7738021217089864, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('ru', 0, 0, 'c', 0.7738021217089864, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('ru', 0, 0, 'n', -0.7738021217089864, array([1, 1, 1, ..., 1, 1, 1])),
#  ('ru', 0, 0, 'ct', 0.7738021217089864, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('ru', 0, 5, 't', 0.84328264406331, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('ru', 0, 5, 'c', 0.8436811632672759, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('ru', 0, 5, 'n', 0.21172882235459697, array([ 1,  1, -1, ...,  1,  1, -1])),
#  ('ru', 0, 5, 'ct', 0.8588360211344228, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('ru', 0, 10, 't', 0.20651551697979018, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('ru', 0, 10, 'c', 0.5324680662773398, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('ru', 0, 10, 'n', 0.7583278954636379, array([-1,  1, -1, ...,  1, -1, -1])),
#  ('ru',
#   0,
#   10,
#   'ct',
#   0.27395343870775923,
#   array([-1,  1, -1, ..., -1, -1, -1])),
#  ('ru', 5, 0, 't', 1.0249540850055252, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('ru', 5, 0, 'c', 1.0890636559167464, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('ru', 5, 0, 'n', 0.1913482906587562, array([ 1,  1, -1, ...,  1,  1, -1])),
#  ('ru', 5, 0, 'ct', 0.9824878144432775, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('ru', 5, 5, 't', 0.8496015115337284, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('ru', 5, 5, 'c', 1.0069617322440563, array([-1,  1, -1, ...,  1, -1, -1])),
#  ('ru', 5, 5, 'n', 0.7651514772966801, array([-1,  1, -1, ...,  1, -1, -1])),
#  ('ru', 5, 5, 'ct', 0.7369517096366462, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('ru', 5, 10, 't', 1.1905601731043338, array([-1,  1, -1, ...,  1, -1, -1])),
#  ('ru', 5, 10, 'c', 0.9626778324447464, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('ru', 5, 10, 'n', 0.9790456280662495, array([-1,  1, -1, ...,  1,  1, -1])),
#  ('ru', 5, 10, 'ct', 1.179809830394622, array([-1,  1, -1, ...,  1, -1, -1])),
#  ('ru', 10, 0, 't', 0.5178466616644584, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('ru', 10, 0, 'c', 0.591909777829545, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('ru', 10, 0, 'n', 0.5890903060066843, array([-1,  1, -1, ...,  1, -1, -1])),
#  ('ru',
#   10,
#   0,
#   'ct',
#   0.49864369107064127,
#   array([-1,  1, -1, ..., -1, -1, -1])),
#  ('ru', 10, 5, 't', 0.7738021217089864, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('ru', 10, 5, 'c', 0.5385548504017154, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('ru', 10, 5, 'n', 0.6509666738095586, array([-1,  1, -1, ...,  1, -1, -1])),
#  ('ru', 10, 5, 'ct', 0.7738021217089864, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('ru', 10, 10, 't', 1.4169547008045285, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('ru', 10, 10, 'c', 1.2708972778608827, array([-1,  1, -1, ...,  1, -1, -1])),
#  ('ru', 10, 10, 'n', 1.4348584547706462, array([-1,  1, -1, ...,  1, -1, -1])),
#  ('ru', 10, 10, 'ct', 1.465106761909575, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('v', 0, 0, 't', 0.665079769427202, array([1, 1, 1, ..., 1, 1, 1])),
#  ('v', 0, 0, 'c', 0.665079769427202, array([1, 1, 1, ..., 1, 1, 1])),
#  ('v', 0, 0, 'n', 0.665079769427202, array([1, 1, 1, ..., 1, 1, 1])),
#  ('v', 0, 0, 'ct', 0.665079769427202, array([1, 1, 1, ..., 1, 1, 1])),
#  ('v', 0, 5, 't', 0.5518206842916255, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('v', 0, 5, 'c', 0.040070529231710304, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('v', 0, 5, 'n', -0.12755326697570915, array([ 1, -1,  1, ..., -1, -1,  1])),
#  ('v', 0, 5, 'ct', 0.6134506180887574, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('v', 0, 10, 't', 1.1647189307395793, array([ 1,  1,  1, ...,  1, -1, -1])),
#  ('v', 0, 10, 'c', 0.9562463909038937, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('v', 0, 10, 'n', 0.7928904651195209, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('v', 0, 10, 'ct', 0.8225105882808204, array([1, 1, 1, ..., 1, 1, 1])),
#  ('v', 5, 0, 't', 0.48576284251111645, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('v', 5, 0, 'c', 0.31218528440796667, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('v', 5, 0, 'n', -0.020250933301445746, array([ 1, -1,  1, ..., -1, -1,  1])),
#  ('v', 5, 0, 'ct', 0.7588399239608854, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('v', 5, 5, 't', 0.743462585537029, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('v', 5, 5, 'c', 0.049959321876992195, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('v', 5, 5, 'n', 0.008787339568083764, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('v', 5, 5, 'ct', 0.8219982464855093, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('v', 5, 10, 't', 1.0721728281262344, array([ 1,  1,  1, ...,  1, -1, -1])),
#  ('v', 5, 10, 'c', 1.0013850682876977, array([ 1,  1,  1, ...,  1, -1, -1])),
#  ('v', 5, 10, 'n', 1.030066215727202, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('v', 5, 10, 'ct', 0.802905395689428, array([1, 1, 1, ..., 1, 1, 1])),
#  ('v', 10, 0, 't', 1.1079257042774708, array([ 1, -1,  1, ...,  1, -1,  1])),
#  ('v', 10, 0, 'c', 1.0874582515019904, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('v', 10, 0, 'n', 0.9286280716476942, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('v', 10, 0, 'ct', 0.8465402452178205, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('v', 10, 5, 't', 1.1565072610851261, array([ 1,  1,  1, ...,  1, -1,  1])),
#  ('v', 10, 5, 'c', 0.7274242309634492, array([ 1,  1,  1, ...,  1, -1, -1])),
#  ('v', 10, 5, 'n', 0.6539097228239504, array([ 1,  1,  1, ...,  1, -1, -1])),
#  ('v', 10, 5, 'ct', 1.0522222278253581, array([1, 1, 1, ..., 1, 1, 1])),
#  ('v', 10, 10, 't', 0.988484483551891, array([1, 1, 1, ..., 1, 1, 1])),
#  ('v', 10, 10, 'c', 1.0721102718035138, array([ 1,  1,  1, ...,  1,  1, -1])),
#  ('v', 10, 10, 'n', 0.9724040266912758, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('v', 10, 10, 'ct', 1.3943790008361792, array([1, 1, 1, ..., 1, 1, 1])),
#  ('y', 0, 0, 't', 0.1947122840484804, array([1, 1, 1, ..., 1, 1, 1])),
#  ('y', 0, 0, 'c', -0.1947122840484804, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('y', 0, 0, 'n', 0.1947122840484804, array([1, 1, 1, ..., 1, 1, 1])),
#  ('y', 0, 0, 'ct', 0.1947122840484804, array([1, 1, 1, ..., 1, 1, 1])),
#  ('y', 0, 5, 't', 1.0854684858244303, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 0, 5, 'c', 0.8081870397652561, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 0, 5, 'n', 0.8778925023426493, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 0, 5, 'ct', 1.3673707785908231, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 0, 10, 't', 1.4539463187111472, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 0, 10, 'c', 1.446526101787972, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 0, 10, 'n', 1.3719020809905993, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 0, 10, 'ct', 1.6970026865026298, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 0, 't', 0.9957926295404689, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 0, 'c', 0.9327689111304229, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 0, 'n', 0.9018262941905032, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 0, 'ct', 1.528228068379178, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 5, 't', 1.0786892913907349, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 5, 'c', 0.824880449789837, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 5, 'n', 0.9117157066906895, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 5, 'ct', 1.5057178602971608, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 10, 't', 1.2974207865305996, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 10, 'c', 1.1025149308804696, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 10, 'n', 0.9967804967797392, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 5, 10, 'ct', 1.4706621637075228, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 0, 't', 1.4653285897205626, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 0, 'c', 1.454387552022677, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 0, 'n', 1.3668794856830158, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 0, 'ct', 1.6607010813083973, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 5, 't', 1.8035552480403896, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 5, 'c', 1.396292236465412, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 5, 'n', 1.1997638484697122, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 5, 'ct', 1.6751018870226486, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 10, 't', 1.5865109074580137, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 10, 'c', 1.4460448245886746, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 10, 'n', 1.3479517934549754, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('y', 10, 10, 'ct', 1.6783086167264427, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('zn', 0, 0, 't', 0.5180964993981352, array([1, 1, 1, ..., 1, 1, 1])),
#  ('zn', 0, 0, 'c', 0.5180964993981352, array([1, 1, 1, ..., 1, 1, 1])),
#  ('zn', 0, 0, 'n', 0.5180964993981352, array([1, 1, 1, ..., 1, 1, 1])),
#  ('zn', 0, 0, 'ct', 0.5180964993981352, array([1, 1, 1, ..., 1, 1, 1])),
#  ('zn', 0, 5, 't', 1.040118785979496, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('zn', 0, 5, 'c', 0.6852979607613489, array([-1, -1, -1, ..., -1,  1, -1])),
#  ('zn', 0, 5, 'n', 0.563577708201083, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('zn', 0, 5, 'ct', 1.00978724071695, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('zn', 0, 10, 't', 1.2641279439903592, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 0, 10, 'c', 1.3358715263136263, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 0, 10, 'n', 1.1505029452193951, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 0, 10, 'ct', 1.4016711936110153, array([-1, -1,  1, ...,  1, -1, -1])),
#  ('zn', 5, 0, 't', 0.9974764638250658, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('zn', 5, 0, 'c', 0.9188536222527773, array([-1, -1, -1, ..., -1,  1, -1])),
#  ('zn', 5, 0, 'n', 0.650939309469052, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('zn', 5, 0, 'ct', 0.8761053382582287, array([-1, -1, -1, ...,  1,  1, -1])),
#  ('zn', 5, 5, 't', 1.1406944770222864, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 5, 5, 'c', 0.5613253703288495, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 5, 5, 'n', 0.8151033162710265, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 5, 5, 'ct', 1.2938513889088148, array([-1, -1,  1, ..., -1, -1,  1])),
#  ('zn', 5, 10, 't', 1.1234687033660222, array([-1, -1,  1, ...,  1, -1, -1])),
#  ('zn', 5, 10, 'c', 1.0098315526826742, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 5, 10, 'n', 1.003126732910617, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 5, 10, 'ct', 1.1551436383150666, array([-1, -1,  1, ...,  1, -1, -1])),
#  ('zn', 10, 0, 't', 1.3780968519534929, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 10, 0, 'c', 0.9507292660642408, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 10, 0, 'n', 0.9760123039762367, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 10, 0, 'ct', 1.3992455318720172, array([-1, -1,  1, ...,  1, -1,  1])),
#  ('zn', 10, 5, 't', 0.5180964993981352, array([1, 1, 1, ..., 1, 1, 1])),
#  ('zn', 10, 5, 'c', 1.1911838977397122, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 10, 5, 'n', 0.9630260218995418, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 10, 5, 'ct', 0.5180964993981352, array([1, 1, 1, ..., 1, 1, 1])),
#  ('zn',
#   10,
#   10,
#   't',
#   0.47031500881520577,
#   array([-1, -1,  1, ..., -1, -1,  1])),
#  ('zn', 10, 10, 'c', 0.9569799692674454, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('zn', 10, 10, 'n', 0.7082891248905111, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('zn',
#   10,
#   10,
#   'ct',
#   0.3991210095352347,
#   array([-1, -1,  1, ..., -1, -1,  1]))]

# %%
arma_best = []
for col_name in actual_returns.columns:
    arma_best.append(max([i for i in arima_perf if i[0] == col_name], key=lambda x:x[-2]))

# %%
arma_best
# Out:
# [('CF', 10, 10, 'n', 1.5103244898646566, array([-1,  1, -1, ...,  1, -1, -1])),
#  ('SR', 0, 5, 'ct', 0.7723613610922581, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('TA', 10, 0, 'c', 1.7828327176809273, array([-1, -1, -1, ...,  1, -1, -1])),
#  ('al', 0, 10, 'ct', 2.159688367983888, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('au', 0, 5, 'ct', 1.6630100222592945, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('c', 5, 0, 't', 0.8413422966671089, array([ 1, -1,  1, ...,  1,  1,  1])),
#  ('cu', 0, 5, 'n', 0.9302024787318378, array([-1, -1, -1, ..., -1, -1, -1])),
#  ('l', 0, 10, 'c', 0.9607541148539618, array([ 1, -1,  1, ...,  1, -1, -1])),
#  ('m', 5, 5, 'c', 0.9687454222503052, array([-1, -1,  1, ..., -1, -1, -1])),
#  ('p', 10, 10, 't', 2.2676668187286926, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('rb', 0, 0, 't', 1.2170057486592645, array([1, 1, 1, ..., 1, 1, 1])),
#  ('ru', 10, 10, 'ct', 1.465106761909575, array([-1,  1, -1, ..., -1, -1, -1])),
#  ('v', 10, 10, 'ct', 1.3943790008361792, array([1, 1, 1, ..., 1, 1, 1])),
#  ('y', 10, 5, 't', 1.8035552480403896, array([-1,  1, -1, ..., -1,  1, -1])),
#  ('zn', 0, 10, 'ct', 1.4016711936110153, array([-1, -1,  1, ...,  1, -1, -1]))]

# %%
arma_signal = np.hstack([i[-1].reshape(-1, 1) for i in arma_best])

# %%
sharpe_ratio(actual_returns, arma_signal)
# Out:
# 5.055824446761724

# %%
for idx, i in enumerate(arma_best):
    sp, mean, std, accu = sharpe_ratio(actual_returns[i[0]], i[-1].reshape(-1), return_stat=True, return_accumulate=True)
    print(f"recorded result {i[4]} calculated result {} inarray result {sharpe_ratio(actual_returns[i[0]], arma_signal[:, idx])}")
# Out:
# recorded result 1.5103244898646566 calculated result 1.5103244898646566 inarray result 1.5103244898646566
# recorded result 0.7723613610922581 calculated result 0.7723613610922581 inarray result 0.7723613610922581
# recorded result 1.7828327176809273 calculated result 1.7828327176809273 inarray result 1.7828327176809273
# recorded result 2.159688367983888 calculated result 2.159688367983888 inarray result 2.159688367983888
# recorded result 1.6630100222592945 calculated result 1.6630100222592945 inarray result 1.6630100222592945
# recorded result 0.8413422966671089 calculated result 0.8413422966671089 inarray result 0.8413422966671089
# recorded result 0.9302024787318378 calculated result 0.9302024787318378 inarray result 0.9302024787318378
# recorded result 0.9607541148539618 calculated result 0.9607541148539618 inarray result 0.9607541148539618
# recorded result 0.9687454222503052 calculated result 0.9687454222503052 inarray result 0.9687454222503052
# recorded result 2.2676668187286926 calculated result 2.2676668187286926 inarray result 2.2676668187286926
# recorded result 1.2170057486592645 calculated result 1.2170057486592645 inarray result 1.2170057486592645
# recorded result 1.465106761909575 calculated result 1.465106761909575 inarray result 1.465106761909575
# recorded result 1.3943790008361792 calculated result 1.3943790008361792 inarray result 1.3943790008361792
# recorded result 1.8035552480403896 calculated result 1.8035552480403896 inarray result 1.8035552480403896
# recorded result 1.4016711936110153 calculated result 1.4016711936110153 inarray result 1.4016711936110153

# %%
df.columns.name

# %%
for col in actual_returns.columns:
    col_data = [i for i in arima_perf if i[0] == col]
    fig, ax = plt.subplots(2,2,figsize=(5, 5))
    for idx, trend in enumerate(('ct', 't', 'n', 'c')):
        x = int(idx / 2)
        y = idx % 2
        # ax = fig.add_subplot(2,2, idx+1)
        trend_data = [i for i in col_data if i[3] == trend]
        df = pd.DataFrame(index=range(0, 11, 5), columns=range(0, 11, 5))
        df.index.name='MA'
        df.columns.name="AR"
        for i in trend_data:
            df[i[1]].loc[i[2]] = i[4]
        sns.heatmap(data=df, ax=ax[x][y])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [79], in <cell line: 1>()
#      12 for i in trend_data:
#      13     df[i[1]].loc[i[2]] = i[4]
# ---> 14 sns.heatmap(data=df, ax=ax[x][y])
#
# File ~/anaconda3/envs/torch38/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/anaconda3/envs/torch38/lib/python3.8/site-packages/seaborn/matrix.py:553, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551 if square:
#     552     ax.set_aspect("equal")
# --> 553 plotter.plot(ax, cbar_ax, kwargs)
#     554 return ax
#
# File ~/anaconda3/envs/torch38/lib/python3.8/site-packages/seaborn/matrix.py:302, in _HeatMapper.plot(self, ax, cax, kws)
#     299     kws.setdefault("vmax", self.vmax)
#     301 # Draw the heatmap
# --> 302 mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
#     304 # Set the axis limits
#     305 ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
#
# File ~/anaconda3/envs/torch38/lib/python3.8/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/torch38/lib/python3.8/site-packages/matplotlib/axes/_axes.py:6070, in Axes.pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6066 C = C.ravel()
#    6068 kwargs.setdefault('snap', rcParams['pcolormesh.snap'])
# -> 6070 collection = mcoll.QuadMesh(
#    6071     coords, antialiased=antialiased, shading=shading,
#    6072     array=C, cmap=cmap, norm=norm, alpha=alpha, **kwargs)
#    6073 collection._scale_norm(norm, vmin, vmax)
#    6074 self._pcolor_grid_deprecation_helper()
#
# File ~/anaconda3/envs/torch38/lib/python3.8/site-packages/matplotlib/collections.py:2016, in QuadMesh.__init__(self, *args, **kwargs)
#    2013 self._bbox.update_from_data_xy(self._coordinates.reshape(-1, 2))
#    2014 # super init delayed after own init because array kwarg requires
#    2015 # self._coordinates and self._shading
# -> 2016 super().__init__(**kwargs)
#
# File ~/anaconda3/envs/torch38/lib/python3.8/site-packages/matplotlib/collections.py:221, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     218 self._transOffset = transOffset
#     220 self._path_effects = None
# --> 221 self.update(kwargs)
#     222 self._paths = None
#
# File ~/anaconda3/envs/torch38/lib/python3.8/site-packages/matplotlib/artist.py:1066, in Artist.update(self, props)
#    1063             if not callable(func):
#    1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
# -> 1066             ret.append(func(v))
#    1067 if ret:
#    1068     self.pchanged()
#
# File ~/anaconda3/envs/torch38/lib/python3.8/site-packages/matplotlib/collections.py:2077, in QuadMesh.set_array(self, A)
#    2072     if faulty_data:
#    2073         raise TypeError(
#    2074             f"Dimensions of A {A.shape} are incompatible with "
#    2075             f"X ({width}) and/or Y ({height})")
# -> 2077 return super().set_array(A)
#
# File ~/anaconda3/envs/torch38/lib/python3.8/site-packages/matplotlib/cm.py:477, in ScalarMappable.set_array(self, A)
#     475 A = cbook.safe_masked_invalid(A, copy=True)
#     476 if not np.can_cast(A.dtype, float, "same_kind"):
# --> 477     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     478                     "converted to float")
#     480 self._A = A
#
# TypeError: Image data of dtype object cannot be converted to float
